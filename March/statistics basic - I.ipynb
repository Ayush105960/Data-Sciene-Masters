# %% [markdown]
# ## 1.

# %% [markdown]
#     Statistics : It is the science of collecting , organizing and analyzing the data sets.

# %% [markdown]
# ## 2.

# %% [markdown]
#     Basically , there are two types of statistics: <\br>
#         |Types of Statistics| Use cases|
#         |Descriptive Statistics | Finding the average salary of the people working as Data Scientist|
#         |Inferential Statistics | Exit poll of elections |

# %% [markdown]
#     Descriptive statistics basically used to summarize and describe the characteristics of the dataset , while
#     Inferential statistics used to make inferences about population dataset based on the sample dataset.

# %% [markdown]
# ## 3.

# %% [markdown]
#     Basically , there are two types of data :
#         1. Qualitative Data
#                 1.Nominal Data : Blood Group .
#                 2.Ordinal Data : Divisions of Exam Scores (I , II , III )
#         2. Quantitative data
#                 1.Discrete data : Runs Scored by Rohit Sharma.
#                 2.Continuous Data : Weight of a person.

# %% [markdown]
# ## 4.

# %% [markdown]
#     (i) : Ordinal Data.
#     (ii): Nominal Data.
#     (iii): Continuous Data.
#     (iv) : Discrete Data.

# %% [markdown]
# ## 5.

# %% [markdown]
#     Levels of measurement is the criterion of data that tells how precisely data are recorded in variables.

# %% [markdown]
#     Four levels of measurement:
#         1. Nominal levels of measurement: Gender , Ethnicity , Blood group , Car Brands , Marital Status , People Face Colour.
#         2.Ordinal levels of measurement : 5 medalists in Olympic , Test Rankings of Cricketers.
#         3. Interval levels of measurement: Temperature Prediction , IQ .
#         4. Ratio levels of measurement : Height , Weight , Age , Temperature in Kalvin.

# %% [markdown]
# ## 6.

# %% [markdown]
#     It's important to understand the levels of measurement so that we can apply appropriate assumptions based on the
#     type of level of measurement .Different levels of measurement need to be approached differentally statistically.

# %% [markdown]
# ![Screenshot%202023-03-25%20144850.png](attachment:Screenshot%202023-03-25%20144850.png)

# %% [markdown]
# ## 7.

# %% [markdown]
#     Ordinal data is different from Nominal data majorly by the fact that nominal can't be ordered/ranked while ordinal can be ranked.

# %% [markdown]
# ## 8.

# %% [markdown]
#     Histograms can be used to display data based on the interval range.

# %% [markdown]
# ## 9.

# %% [markdown]
#     Major Differences:
#     1. Descriptive statistics deals with the raw data and then summarizes telling its description about features while , Inferential Statistics makes the inferences about population data based on the sample data.
#     2. We use Descriptive Statistics to describe a situation while we use inferential statistics to tell the probability of occurrence of an event.
#     3. Descriptive statistics is used to analyze and summmarize the data while inferential statistics is used to create inferences , hypotheses and predictionss.
#     4. We use charts , graphs and tables for descriptive statistics while we use probability methods for inferential statistics.

# %% [markdown]
# ## 10.

# %% [markdown]
#     common measures of central tendancy :
#         Mean , Median and Mode.
#     Common measures of Variability :
#         Standard Deviation and Variance.

# %% [markdown]
#     Measures of central tendency are summary statistics that represent the center point or typical value of a dataset. Examples of these measures include the mean, median, and mode. These statistics indicate where most values in a distribution fall and are also referred to as the central location of a distribution. You can think of central tendency as the propensity for data points to cluster around a middle value.

# %% [markdown]
#     While Measures of Variability tells how much the data is spread overall .A measure of variability is a summary statistic that represents the amount of dispersion in a dataset. How spread out are the values? While a measure of central tendency describes the typical value, measures of variability define how far away the data points tend to fall from the center. We talk about variability in the context of a distribution of values. A low dispersion indicates that the data points tend to be clustered tightly around the center. High dispersion signifies that they tend to fall further away.
